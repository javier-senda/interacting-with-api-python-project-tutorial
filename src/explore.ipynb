# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# load the .env file variables
load_dotenv()

client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

# Paso 4: Inicializar la biblioteca de Spotipy
auth_manager=SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)

sp=spotipy.Spotify(auth_manager=auth_manager)

# Paso 5: Realizar solicitidus a la API
postmalone_uri="https://open.spotify.com/intl-es/artist/246dkjvS1zLTtiykXe5h60"

top10 = sp.artist_top_tracks(artist_id="246dkjvS1zLTtiykXe5h60")

tracks = [{"name":i["name"], "popularity": i["popularity"], "duration": i["duration_ms"]} for i in top10["tracks"]]

# Paso 6: Transformar a Pandas Dataframe y mostrar el top 3 resultante
df = pd.DataFrame(tracks)

df["duration"] = df["duration"] / 1000

df_sorted = df.sort_values(by="popularity", ascending=True)

print(df_sorted.head(3))

# Paso 7: Analizar relación estadística
plt.figure(figsize=(7, 5))
plt.scatter(df["duration"], df["popularity"], color="red")

plt.xlabel("Duración (s)")
plt.ylabel("Popularidad")
plt.title("Relación entre duración y popularidad de canciones")

plt.show()
# Out:
#                                     name  popularity  duration
# 9  Pour Me A Drink (Feat. Blake Shelton)          69   195.122
# 5        Guy For That (Feat. Luke Combs)          73   164.011
# 7          Dial Drunk (with Post Malone)          74   213.817
# Bad pipe message: %s [b'0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nHost: localhost:33881\r\nUs', b'-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.']
# Bad pipe message: %s [b'0.0 Safari/537.36\r\nAccept-Encoding: gzip, defla']
# Bad pipe message: %s [b', br, zstd\r\nAccept-Language: es-ES,es;q=0.9\r\nCache-Control: max-age=0\r\nReferer: https://github.com/\r\nX-Request-ID: ', b'25cf1f4065c9499225b9f8e41e3038\r\nX-Real-IP: 10.240.2.131\r\nX-Forwarded-Port: 443\r\nX-Forwarded-Scheme:', b'ttps\r\nX-Original-URI: /\r\nX-Sche']
# Bad pipe message: %s [b': https\r\nsec-fetch-site: cross-site\r\nsec-fetch-mode: navigate\r\nsec-fetch-dest: document\r\nsec-ch-ua: "Chromiu', b';v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"\r\nsec-ch-ua-mobile: ?0\r\nsec-ch-ua-platform: "Windows"']
# Bad pipe message: %s [b'priority: u=']
# Bad pipe message: %s [b' i\r\nX-Original-Proto: https\r\nCookie: _hjSession']
# Bad pipe message: %s [b'er_5196661=eyJpZCI6IjU0MjNjYjcxLWM0Y2MtNTY2Mi1iMTI5LWQyODFiMDBkN2MzYiIsImNyZWF0ZWQiO', b'3MzgwMDg1Njg0MjcsImV4aXN0aW5nIjp0cnVlfQ==; _ga_2B75G58TF7=GS1.1.1741544096.27.1.1741546288.0.0.0\r\nX-Forwa', b'ed-Proto: https\r\nX-Forwarded-Host: effective-parakeet-7vr6pv9p5wpw2rgp6-33881.app.github.dev\r\nX-Forwarded-For: 10']

# %% [markdown]
# No parece haber excesiva relación entre la duración y la popularidad, ya que, por ejemplo, las 3 más populares son dispares en su duración
